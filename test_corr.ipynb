# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame, Panel

# %%
ao = np.loadtxt('D://monthly.ao.index.b50.current.ascii')

# %%
ao[0:2]
# Out:
# array([[  1.95000000e+03,   1.00000000e+00,  -6.03100000e-02],
#        [  1.95000000e+03,   2.00000000e+00,   6.26810000e-01]])

# %%
ao.shape
# Out:
# (806, 3)

# %%
dates = pd.date_range('1950-01', '2017-03', freq='M')

# %%
dates
# Out:
# DatetimeIndex(['1950-01-31', '1950-02-28', '1950-03-31', '1950-04-30',
#                '1950-05-31', '1950-06-30', '1950-07-31', '1950-08-31',
#                '1950-09-30', '1950-10-31',
#                ...
#                '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31',
#                '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31',
#                '2017-01-31', '2017-02-28'],
#               dtype='datetime64[ns]', length=806, freq='M')

# %%
dates.shape
# Out:
# (806,)

# %%
AO = pd.Series(ao[:,2], index=dates)

# %%
AO.plot()

# %%
AO['1980':'1990'].plot()

# %%
AO['1980-05':'1981-03'].plot()

# %%
AO['2016']
# Out:
# 2016-01-31   -1.448700
# 2016-02-29   -0.023521
# 2016-03-31    0.280240
# 2016-04-30   -1.051100
# 2016-05-31   -0.035739
# 2016-06-30    0.312880
# 2016-07-31    0.084758
# 2016-08-31    0.472380
# 2016-09-30    0.780970
# 2016-10-31   -1.917300
# 2016-11-30   -0.610910
# 2016-12-31    1.786400
# Freq: M, dtype: float64

# %%
AO['1960']
# Out:
# 1960-01-31   -2.484200
# 1960-02-29   -2.212400
# 1960-03-31   -1.624600
# 1960-04-30   -0.297310
# 1960-05-31   -0.857430
# 1960-06-30    0.054978
# 1960-07-31   -0.619060
# 1960-08-31   -1.007900
# 1960-09-30   -0.381640
# 1960-10-31   -1.187000
# 1960-11-30   -0.553230
# 1960-12-31   -0.342950
# Freq: M, dtype: float64

# %%
nao = np.loadtxt('D://norm.nao.monthly.b5001.current.ascii')
dates_nao = pd.date_range('1950-01', '2017-03', freq='M')
NAO = Series(nao[:,2], index=dates_nao)

# %%
NAO.index
# Out:
# DatetimeIndex(['1950-01-31', '1950-02-28', '1950-03-31', '1950-04-30',
#                '1950-05-31', '1950-06-30', '1950-07-31', '1950-08-31',
#                '1950-09-30', '1950-10-31',
#                ...
#                '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31',
#                '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31',
#                '2017-01-31', '2017-02-28'],
#               dtype='datetime64[ns]', length=806, freq='M')

# %%
aonao = DataFrame({'AO' : AO, 'NAO' : NAO})

# %%
aonao.plot()

# %%
aonao.head()
# Out:
#                   AO   NAO
# 1950-01-31 -0.060310  0.92
# 1950-02-28  0.626810  0.40
# 1950-03-31 -0.008127 -0.36
# 1950-04-30  0.555100  0.73
# 1950-05-31  0.071577 -0.59

# %%
aonao.NAO
# Out:
# 1950-01-31    0.920000
# 1950-02-28    0.400000
# 1950-03-31   -0.360000
# 1950-04-30    0.730000
# 1950-05-31   -0.590000
# 1950-06-30   -0.060000
# 1950-07-31   -1.260000
# 1950-08-31   -0.050000
# 1950-09-30    0.250000
# 1950-10-31    0.850000
# 1950-11-30   -1.260000
# 1950-12-31   -1.020000
# 1951-01-31    0.080000
# 1951-02-28    0.700000
# 1951-03-31   -1.020000
# 1951-04-30   -0.220000
# 1951-05-31   -0.590000
# 1951-06-30   -1.640000
# 1951-07-31    1.370000
# 1951-08-31   -0.220000
# 1951-09-30   -1.360000
# 1951-10-31    1.870000
# 1951-11-30   -0.390000
# 1951-12-31    1.320000
# 1952-01-31    0.930000
# 1952-02-29   -0.830000
# 1952-03-31   -1.490000
# 1952-04-30    1.010000
# 1952-05-31   -1.120000
# 1952-06-30   -0.400000
#                 ...
# 2014-09-30    1.616300
# 2014-10-31   -1.270600
# 2014-11-30    0.677970
# 2014-12-31    1.857500
# 2015-01-31    1.788700
# 2015-02-28    1.322800
# 2015-03-31    1.449700
# 2015-04-30    0.725350
# 2015-05-31    0.145520
# 2015-06-30   -0.066822
# 2015-07-31   -3.179000
# 2015-08-31   -0.760360
# 2015-09-30   -0.648460
# 2015-10-31    0.437230
# 2015-11-30    1.743800
# 2015-12-31    2.243600
# 2016-01-31    0.116520
# 2016-02-29    1.580300
# 2016-03-31    0.734400
# 2016-04-30    0.375140
# 2016-05-31   -0.773580
# 2016-06-30   -0.432510
# 2016-07-31   -1.760300
# 2016-08-31   -1.645300
# 2016-09-30    0.610960
# 2016-10-31    0.411250
# 2016-11-30   -0.163660
# 2016-12-31    0.478330
# 2017-01-31    0.478240
# 2017-02-28    1.004800
# Freq: M, Name: NAO, dtype: float64

# %%
aonao['Diff'] = aonao['AO'] - aonao['NAO']
aonao.head()
# Out:
#                   AO   NAO      Diff
# 1950-01-31 -0.060310  0.92 -0.980310
# 1950-02-28  0.626810  0.40  0.226810
# 1950-03-31 -0.008127 -0.36  0.351872
# 1950-04-30  0.555100  0.73 -0.174900
# 1950-05-31  0.071577 -0.59  0.661577

# %%
del aonao['Diff']
aonao.tail()
# Out:
#                  AO      NAO
# 2016-10-31 -1.91730  0.41125
# 2016-11-30 -0.61091 -0.16366
# 2016-12-31  1.78640  0.47833
# 2017-01-31  0.94197  0.47824
# 2017-02-28  0.33986  1.00480

# %%
aonao['1981-01':'1981-03']
# Out:
#                  AO   NAO
# 1981-01-31 -0.11634  0.37
# 1981-02-28 -0.33158  0.92
# 1981-03-31 -1.64470 -1.19

# %%
import datetime
aonao.ix[(aonao.AO > 0) & (aonao.NAO < 0) 
        & (aonao.index > datetime.datetime(1980,1,1)) 
        & (aonao.index < datetime.datetime(1989,1,1)),
        'NAO'].plot(kind='barh')

# %%
pd.rolling_corr(aonao.AO, aonao.NAO, window=120).plot(style='-g')
# Out:
# C:\Users\capec\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: pd.rolling_corr is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=120).corr(other=<Series>)
#   if __name__ == '__main__':

# %%
aonao.corr()
# Out:
#            AO       NAO
# AO   1.000000  0.605433
# NAO  0.605433  1.000000
