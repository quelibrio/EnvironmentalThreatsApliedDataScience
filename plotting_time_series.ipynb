# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# plots time series from a dataFrame. The first column must be a series of dates/hours.
# The other columns are for the time series we might want to compare.
def plot_date_series(data_frame):
    rows, cols = data_frame.axes
    for ys in cols[1:]:
        plt.plot_date(x=data_frame[cols[0]], y=data_frame[ys], fmt='-', label=ys)

# %%
df = pd.read_csv("date_series2.csv")
df.head()
# Out:
#          Date   Series1   Series2
# 0  2012-01-23       147       123
# 1  2012-01-24       157        32
# 2  2012-01-25       156        44
# 3  2012-01-26       158       343
# 4  2012-01-27       139        45

# %%
plt.figure(figsize=(10, 10))
plot_date_series(df)

# %%
plt.grid(True)
plt.title('graph title')
plt.legend(loc='lower right')
plt.ylabel('y-axis label')
plt.show()
